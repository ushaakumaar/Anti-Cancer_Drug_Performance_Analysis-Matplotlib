# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
number_of_mice = len(mouse_df["Mouse ID"].unique())
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup_mouse_df = mouse_df[mouse_df.duplicated(["Mouse ID","Timepoint"], keep=False)]
dup_mouse_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_mouse_df = mouse_df.loc[mouse_df["Mouse ID"] != "g989"]
cleaned_mouse_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice_now = len(cleaned_mouse_df["Mouse ID"].unique())
number_of_mice_now
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

# Calculate Average of Tumor Volume per Drug Regimen
mean_stats = cleaned_mouse_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()

# Calculate Median of Tumor Volume per Drug Regimen
median_stats = cleaned_mouse_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()

# Calculate Variance of Tumor Volume per Drug Regimen
var_stats = cleaned_mouse_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()

# Calculate Standard Deviation of Tumor Volume per Drug Regimen
std_stats = cleaned_mouse_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()

# Calculate SEM of Tumor Volume per Drug Regimen
sem_stats = cleaned_mouse_df.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

# Create a DataFrame to hold above calculated statistics
stats_summary = pd.DataFrame({
    "mean" : mean_stats,
    "median": median_stats,
    "var" : var_stats,
    "std" : std_stats,
    "sem" : sem_stats
})
stats_summary
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
summary_stats = cleaned_mouse_df.groupby("Drug Regimen").agg({
    "Tumor Volume (mm3)" : ["mean", "median","var","std","sem"]
    })
summary_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

# Calculate total number of mice for each treatment
bar_df = cleaned_mouse_df.groupby("Drug Regimen")["Drug Regimen"].count()

# Sort the data in descending order
bar_df.sort_values(inplace = True,
                   ascending = False)

# Create a bar plot using pandas dataframe
bar_df.plot(kind="bar", xlabel="Drug Regimen", ylabel="Number of Data Points")

# Save and Display the bar plot
plt.tight_layout()
plt.savefig("Images/pandas-bar.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

# Set x axis and x axis labels
x_axis = np.arange(len(bar_df))
labels = bar_df.keys()

# Create a bar plot using pyplot
plt.bar(x_axis, bar_df, align="center")

# Assign the x axis labels with vertical orientation
plt.xticks(x_axis, labels, rotation="vertical")

# Set the x axis label and y axis label
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Data Points")

# Save and Display the bar plot
plt.tight_layout()
plt.savefig("Images/pyplot-bar.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Calculate the number of mice for each Sex
pie_df = cleaned_mouse_df.groupby("Sex")["Sex"].count()

# Sort the data in descending order
pie_df.sort_values(inplace = True,
                   ascending = False)

# Generate the pie plot using pandas dataframe
pie_df.plot(kind="pie",autopct="%1.1f%%")

# Save and Display the pie plot
plt.tight_layout()
plt.savefig("Images/pandas-pie.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Labels for the sections of our pie chart
labels = pie_df.keys()

# Generate the pie plot using pyplot
plt.pie(pie_df, labels=labels, autopct="%1.1f%%")

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Set y axis label
plt.ylabel("Sex")

# Save and Display the pie plot
plt.tight_layout()
plt.savefig("Images/pyplot-pie.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoints = cleaned_mouse_df.groupby("Mouse ID")["Timepoint"].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_merged_df = pd.merge(cleaned_mouse_df, last_timepoints,on=("Mouse ID","Timepoint"), how="inner")
new_merged_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#Loop through each treatment
for treatment in treatment_list:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol = new_merged_df.loc[(new_merged_df["Drug Regimen"] == treatment)]["Tumor Volume (mm3)"]
    
    # add subset 
    tumor_vol_data.append(tumor_vol)
    
    # Determine outliers for treatment using upper and lower bounds
    quartiles = tumor_vol.quantile([.25,.75])
    
    # Determine 25th Quartile and 75th Quartile for treatment
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    
    # Calculate the IQR for treatment
    iqr = upperq - lowerq
    
    # Calculate the lower and upper bounds for treatment
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    # Find potential outliers for treatment using the lower and upper bounds
    outliers = tumor_vol.loc[(tumor_vol < lower_bound) | (tumor_vol > upper_bound)]
    if len(outliers) > 0:
        print(f"There is {len(outliers)} Outlier(s) for {treatment}")
        for outlier in outliers:
            print(outlier)
# Out:
# There is 1 Outlier(s) for Infubinol
# 36.321345799999996

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# Set unique color for the outliers
red_dot = dict(markerfacecolor='r', marker='o')

# Generate boxplot 
fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volumes / Treatment - Box Plot')
ax1.boxplot(tumor_vol_data, flierprops=red_dot, labels = treatment_list)

# Set x and y labels
plt.xlabel("Treatments")
plt.ylabel("Final Tumor Volume (mm3)")

# Save and Display the box plot
plt.tight_layout()
plt.savefig("Images/boxplot.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
